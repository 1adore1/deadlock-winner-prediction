# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
start = 'https://tracklock.gg/matches/'
num = 6100010 # 6300004-6329649
games = []
for i in range(10):
    url = start + str(num + i)
    page = requests.get(url)
    soup = BeautifulSoup(page.text, "html.parser")
    etc = soup.findAll('p', class_='text-2xl font-bold text-white font-sapient')
    if not etc:
        continue
    heroes = []
    heroes.append(num + i)
    heroes.append(*etc[3])
    found_heroes = soup.find_all('span', class_='font-medium')
    for hero in found_heroes:
        heroes.append(hero.text)
    games.append(heroes)

len(games)
# Out:
# 6

# %%
df = pd.DataFrame(games)
A_team = ['hero_1_A', 'hero_2_A', 'hero_3_A', 'hero_4_A', 'hero_5_A', 'hero_6_A']
B_team = ['hero_1_B', 'hero_2_B', 'hero_3_B', 'hero_4_B', 'hero_5_B', 'hero_6_B']
df.columns = [['matchid', 'winner'] + A_team + B_team]
df.dropna(inplace=True)
df['matchid'] = df['matchid'].astype(int)
df
# Out:
#    matchid              winner  hero_1_A    hero_2_A    hero_3_A  hero_4_A  \
# 0  6100010  The Sapphire Flame    Pocket  Lady Geist     Paradox  Infernus
# 1  6100011      The Amber Hand    Wraith      Pocket  Lady Geist    Warden
# 2  6100013  The Sapphire Flame      Shiv       Bebop  Lady Geist  Vindicta
# 3  6100014      The Amber Hand  Infernus        Shiv        Haze    Wraith
# 4  6100017  The Sapphire Flame  Vindicta       Seven      Yamato     Bebop
# 5  6100019  The Sapphire Flame  Vindicta     Paradox      Dynamo    Yamato
#
#      hero_5_A  hero_6_A    hero_1_B hero_2_B  hero_3_B    hero_4_B  hero_5_B  \
# 0     Viscous    Kelvin      Warden     Haze      Shiv      Wraith      Lash
# 1  Grey Talon  Vindicta        Haze   Abrams     Seven       Bebop  McGinnis
# 2       Seven    Abrams        Haze     Lash    Dynamo    McGinnis    Warden
# 3      Dynamo     Seven  Lady Geist  Paradox     Bebop      Yamato    Warden
# 4    Infernus  McGinnis        Shiv     Lash      Haze  Grey Talon    Wraith
# 5       Bebop      Haze    Infernus   Wraith  McGinnis      Kelvin     Seven
#
#      hero_6_B
# 0       Bebop
# 1    Infernus
# 2  Grey Talon
# 3    Vindicta
# 4      Pocket
# 5      Pocket

# %%
df.to_csv('data/new_matches.csv', index=False)
