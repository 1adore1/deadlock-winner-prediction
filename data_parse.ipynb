# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
start = 'https://tracklock.gg/matches/'
num = 5700000
games = []
for i in range(20000):
    url = start + str(num + i)
    page = requests.get(url)
    soup = BeautifulSoup(page.text, "html.parser")
    etc = soup.findAll('p', class_='text-2xl font-bold text-white font-sapient')
    if not etc:
        continue
    heroes = []
    heroes.append(num + i)
    heroes.append(*etc[3])
    found_heroes = soup.find_all('span', class_='font-medium')
    for hero in found_heroes:
        heroes.append(hero.text)
    games.append(heroes)

len(games)
# Out:
# 10441

# %%
df = pd.DataFrame(games)
A_team = ['hero_1_A', 'hero_2_A', 'hero_3_A', 'hero_4_A', 'hero_5_A', 'hero_6_A']
B_team = ['hero_1_B', 'hero_2_B', 'hero_3_B', 'hero_4_B', 'hero_5_B', 'hero_6_B']
df.columns = ['matchid', 'winner'] + A_team + B_team
df.dropna(inplace=True)
df['matchid'] = df['matchid'].astype(int)
df
# Out:
#        matchid              winner    hero_1_A  hero_2_A  hero_3_A  \
# 0      5700004  The Sapphire Flame    McGinnis    Pocket   Viscous
# 1      5700007  The Sapphire Flame       Bebop      Haze  Infernus
# 2      5700008      The Amber Hand       Seven    Abrams    Kelvin
# 3      5700012      The Amber Hand      Wraith      Haze    Warden
# 4      5700015  The Sapphire Flame      Warden  Infernus  Vindicta
# ...        ...                 ...         ...       ...       ...
# 10436  5719990      The Amber Hand      Yamato    Wraith    Kelvin
# 10437  5719991  The Sapphire Flame    Vindicta  McGinnis      Lash
# 10438  5719992  The Sapphire Flame      Warden     Bebop      Lash
# 10439  5719995      The Amber Hand  Mo & Krill      Lash   Viscous
# 10440  5719996      The Amber Hand        Haze  Infernus   Viscous
#
#          hero_4_A    hero_5_A    hero_6_A    hero_1_B  hero_2_B    hero_3_B  \
# 0        Vindicta  Lady Geist      Kelvin        Haze    Warden     Paradox
# 1         Viscous         Ivy  Grey Talon      Warden    Dynamo  Lady Geist
# 2         Paradox        Lash      Pocket  Lady Geist    Wraith        Shiv
# 3        Vindicta    Infernus       Bebop    McGinnis   Paradox  Mo & Krill
# 4           Seven      Wraith      Abrams     Viscous      Haze    McGinnis
# ...           ...         ...         ...         ...       ...         ...
# 10436      Pocket        Shiv        Haze       Seven  Infernus    Vindicta
# 10437  Mo & Krill       Bebop     Paradox        Haze    Dynamo    Infernus
# 10438      Pocket      Wraith      Dynamo    Vindicta     Seven    McGinnis
# 10439      Warden       Seven         Ivy    Vindicta  Infernus        Haze
# 10440      Wraith      Abrams    Vindicta       Bebop  McGinnis      Pocket
#
#          hero_4_B    hero_5_B    hero_6_B
# 0          Wraith      Abrams      Yamato
# 1      Mo & Krill        Shiv      Yamato
# 2             Ivy        Haze  Grey Talon
# 3          Yamato      Abrams       Seven
# 4          Pocket  Grey Talon       Bebop
# ...           ...         ...         ...
# 10436         Ivy      Abrams        Lash
# 10437      Wraith  Lady Geist      Yamato
# 10438     Viscous  Grey Talon  Lady Geist
# 10439      Kelvin        Shiv      Yamato
# 10440      Kelvin        Lash      Dynamo
#
# [10408 rows x 14 columns]

# %%
df.to_csv('data/new_matches.csv', index=False)
